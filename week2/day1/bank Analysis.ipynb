# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

path = r"C:\Users\Lenovo\Documents\DE\Week1\DAY 1\stradit-internship\week2\day1\data\creditcard.csv"

bank_df = pd.read_csv(path)

print(bank_df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 import plotyly.express as px
#       6 path = r"C:\Users\Lenovo\Documents\DE\Week1\DAY 1\stradit-internship\week2\day1\data\creditcard.csv"
#       8 bank_df = pd.read_csv(path)
#
# ModuleNotFoundError: No module named 'plotyly'
